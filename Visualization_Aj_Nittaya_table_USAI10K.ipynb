# %%
# open csv
import pandas as pd
dataframe = pd.read_csv('/media/tohn/HDD/Dataset_USAI10K/csv/USAI10K188209_BiTNet_Predicted_All.csv')
dataframe = dataframe.drop(['Unnamed: 0'], axis=1)
# print(dataframe.shape)

# PID and Doctor ID
PID_df = pd.read_csv('/media/tohn/HDD/Dataset_USAI10K/csv/USAI10K_Doctor-all_2013-2023_5FP_15AB_ALL.csv')
PID_df = PID_df.drop(['Unnamed: 0'], axis=1)


dataframe['Doctor_ID'] =  PID_df['Doctor']
dataframe['PID'] =  PID_df['pid']
dataframe  = dataframe.astype({'Doctor_ID': 'object', 'PID': 'object'})
# Out:
# /home/yupaporn/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (31) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
dataframe
# Out:
#                                                  img_path      AB01      AB02  \
# 0       /media/tohn/HDD/Dataset_USAI10K_Cropped/USAI_d...  0.000000  0.000000
# 1       /media/tohn/HDD/Dataset_USAI10K_Cropped/USAI_d...  0.000130  0.002731
# 2       /media/tohn/HDD/Dataset_USAI10K_Cropped/USAI_d...  0.002785  0.005771
# 3       /media/tohn/HDD/Dataset_USAI10K_Cropped/USAI_d...  0.000000  0.000000
# 4       /media/tohn/HDD/Dataset_USAI10K_Cropped/USAI_d...  0.002506  0.000083
# ...                                                   ...       ...       ...
# 188204  /media/tohn/HDD/Dataset_USAI10K_Cropped/USAI_d...  0.005195  0.014653
# 188205  /media/tohn/HDD/Dataset_USAI10K_Cropped/USAI_d...  0.000000  0.000000
# 188206  /media/tohn/HDD/Dataset_USAI10K_Cropped/USAI_d...  0.000000  0.002500
# 188207  /media/tohn/HDD/Dataset_USAI10K_Cropped/USAI_d...  0.005437  0.008216
# 188208  /media/tohn/HDD/Dataset_USAI10K_Cropped/USAI_d...  0.009496  0.006347
#
#             AB03      AB04      AB05      AB06      AB07     AB081     AB082  \
# 0       0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1       0.000522  0.000007  0.003347  0.000021  0.000412  0.000020  0.000000
# 2       0.003057  0.005548  0.006609  0.000398  0.001222  0.008613  0.000428
# 3       0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.005000
# 4       0.001411  0.000083  0.000353  0.000378  0.000000  0.000000  0.000083
# ...          ...       ...       ...       ...       ...       ...       ...
# 188204  0.025440  0.001043  0.015837  0.023229  0.010139  0.007125  0.016006
# 188205  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 188206  0.000000  0.002500  0.000000  0.002500  0.000000  0.000000  0.000000
# 188207  0.011997  0.008159  0.015688  0.003426  0.005131  0.007938  0.011660
# 188208  0.023580  0.013752  0.017113  0.028758  0.007375  0.013168  0.075946
#
#         ...      AB11      AB12    Normal  GroupAB_Abnormolity  \
# 0       ...  0.000000  0.000000  1.000000             ['AB05']
# 1       ...  0.000007  0.000062  0.991341             ['AB05']
# 2       ...  0.000999  0.005531  0.957862             ['AB05']
# 3       ...  0.000000  0.000000  0.995000             ['AB05']
# 4       ...  0.000000  0.002924  0.990423             ['AB05']
# ...     ...       ...       ...       ...                  ...
# 188204  ...  0.031090  0.070014  0.764076           ['Normal']
# 188205  ...  0.000000  0.000000  1.000000           ['Normal']
# 188206  ...  0.000000  0.002500  0.987500           ['Normal']
# 188207  ...  0.010688  0.221290  0.672705           ['Normal']
# 188208  ...  0.024133  0.035008  0.706689           ['Normal']
#
#         category_5FPvit  Prob_5FPvit category_BiTNet Prob_BiTNet  Doctor_ID  \
# 0                  FP-B     0.831097          Normal    1.000000         12
# 1                  FP-B     0.840534          Normal    1.000000         12
# 2                  FP-A     0.851766          Normal    1.000000         12
# 3                  FP-C     0.842169          Normal    1.000000         12
# 4                  FP-C     0.850962          Normal    1.000000         12
# ...                 ...          ...             ...         ...        ...
# 188204             FP-A     0.837009          Normal    0.999823        844
# 188205             FP-C     0.844101          Normal    1.000000        844
# 188206             FP-A     0.846431          Normal    1.000000        844
# 188207             FP-D     0.845614            AB12    0.766093        844
# 188208             FP-C     0.844707          Normal    0.999989        844
#
#          PID
# 0        378
# 1        378
# 2        378
# 3        378
# 4        378
# ...      ...
# 188204  7891
# 188205  7891
# 188206  7891
# 188207  7891
# 188208  7891
#
# [188209 rows x 23 columns]

# %%
did = list(set(dataframe['Doctor_ID']))
did
# Out:
# [10, 12, 844, 465, 1816, 349]

# %%
# only select Nittaya doctor
dataframe_12 = dataframe[dataframe['Doctor_ID'] == 12]
dataframe_12
# Out:
#                                                 img_path      AB01      AB02  \
# 0      /media/tohn/HDD/Dataset_USAI10K_Cropped/USAI_d...  0.000000  0.000000
# 1      /media/tohn/HDD/Dataset_USAI10K_Cropped/USAI_d...  0.000130  0.002731
# 2      /media/tohn/HDD/Dataset_USAI10K_Cropped/USAI_d...  0.002785  0.005771
# 3      /media/tohn/HDD/Dataset_USAI10K_Cropped/USAI_d...  0.000000  0.000000
# 4      /media/tohn/HDD/Dataset_USAI10K_Cropped/USAI_d...  0.002506  0.000083
# ...                                                  ...       ...       ...
# 47700  /media/tohn/HDD/Dataset_USAI10K_Cropped/USAI_d...  0.005500  0.010008
# 47701  /media/tohn/HDD/Dataset_USAI10K_Cropped/USAI_d...  0.005083  0.005655
# 47702  /media/tohn/HDD/Dataset_USAI10K_Cropped/USAI_d...  0.030542  0.014530
# 47703  /media/tohn/HDD/Dataset_USAI10K_Cropped/USAI_d...  0.024680  0.023477
# 47704  /media/tohn/HDD/Dataset_USAI10K_Cropped/USAI_d...  0.004051  0.019431
#
#            AB03      AB04      AB05      AB06      AB07     AB081     AB082  \
# 0      0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1      0.000522  0.000007  0.003347  0.000021  0.000412  0.000020  0.000000
# 2      0.003057  0.005548  0.006609  0.000398  0.001222  0.008613  0.000428
# 3      0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.005000
# 4      0.001411  0.000083  0.000353  0.000378  0.000000  0.000000  0.000083
# ...         ...       ...       ...       ...       ...       ...       ...
# 47700  0.005000  0.002944  0.000464  0.001325  0.002500  0.003125  0.005183
# 47701  0.001155  0.000030  0.000847  0.000441  0.000746  0.002986  0.000012
# 47702  0.006839  0.008637  0.012169  0.001993  0.006096  0.016069  0.016314
# 47703  0.031003  0.007131  0.035381  0.010347  0.012068  0.019028  0.035085
# 47704  0.030511  0.005603  0.010377  0.005522  0.005951  0.004119  0.003679
#
#        ...      AB11      AB12    Normal  GroupAB_Abnormolity  \
# 0      ...  0.000000  0.000000  1.000000             ['AB05']
# 1      ...  0.000007  0.000062  0.991341             ['AB05']
# 2      ...  0.000999  0.005531  0.957862             ['AB05']
# 3      ...  0.000000  0.000000  0.995000             ['AB05']
# 4      ...  0.000000  0.002924  0.990423             ['AB05']
# ...    ...       ...       ...       ...                  ...
# 47700  ...  0.001875  0.007790  0.952591             ['AB09']
# 47701  ...  0.002500  0.030307  0.950003             ['AB09']
# 47702  ...  0.013461  0.140571  0.707615             ['AB09']
# 47703  ...  0.012806  0.068490  0.667621             ['AB09']
# 47704  ...  0.014587  0.099071  0.781121             ['AB09']
#
#        category_5FPvit  Prob_5FPvit category_BiTNet Prob_BiTNet  Doctor_ID  \
# 0                 FP-B     0.831097          Normal    1.000000         12
# 1                 FP-B     0.840534          Normal    1.000000         12
# 2                 FP-A     0.851766          Normal    1.000000         12
# 3                 FP-C     0.842169          Normal    1.000000         12
# 4                 FP-C     0.850962          Normal    1.000000         12
# ...                ...          ...             ...         ...        ...
# 47700             FP-D     0.852227          Normal    1.000000         12
# 47701             FP-D     0.828086          Normal    0.999999         12
# 47702             FP-D     0.848383          Normal    0.996505         12
# 47703             FP-D     0.805708          Normal    0.999999         12
# 47704             FP-E     0.836940          Normal    0.998205         12
#
#         PID
# 0       378
# 1       378
# 2       378
# 3       378
# 4       378
# ...     ...
# 47700  6207
# 47701  6207
# 47702  6207
# 47703  6207
# 47704  6207
#
# [47705 rows x 23 columns]

# %%
# finding  Prob_BiTNet_of15AB
dataframe_12['Prob_BiTNet_ofAbNor'] = dataframe_12['Prob_BiTNet']
prob_max = []

for i in range(len(dataframe_12)):
    prob = dataframe_12.iloc[i,1:16].tolist()
    prob_max.append(max(prob))
    
dataframe_12['Prob_BiTNet_of15AB'] = prob_max
# Out:
# /home/yupaporn/.local/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/yupaporn/.local/lib/python3.6/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
# finding  Result_BiTNet_Currect

GroupAB_Abnormolity = dataframe_12['GroupAB_Abnormolity'].tolist()
category_BiTNet = dataframe_12['category_BiTNet'].tolist()
res =[]

for i in range(len(GroupAB_Abnormolity)):
    
    cla = GroupAB_Abnormolity[i].split('[')[1].split(']')[0].split(', ')
    if f"'{category_BiTNet[i]}'" in cla:
        res.append(1)

    else:
        res.append(0)
        
dataframe_12['Result_BiTNet_Currect'] = res
# Out:
# /home/yupaporn/.local/lib/python3.6/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()

# %%
dataframe_12.groupby(['Result_BiTNet_Currect'])['img_path'].count().reset_index()
# Out:
#    Result_BiTNet_Currect  img_path
# 0                      0     23392
# 1                      1     24313

# %%
dataframe_12 = dataframe_12[['img_path', 'AB01', 'AB02', 'AB03', 'AB04', 'AB05', 'AB06', 'AB07',
       'AB081', 'AB082', 'AB083', 'AB09', 'AB10', 'AB11', 'AB12', 'Normal',
       'GroupAB_Abnormolity', 'category_5FPvit', 'Prob_5FPvit',
       'category_BiTNet', 'Result_BiTNet_Currect', 'Prob_BiTNet_ofAbNor', 'Prob_BiTNet_of15AB', 'Doctor_ID', 'PID']]

# %% [markdown]
# # 🔗sort by the AI-confidence

# %%
dataframe_12_ofAbNor = dataframe_12.sort_values(by='Prob_BiTNet_ofAbNor', ascending=False)
dataframe_12_ofAbNor
# Out:
#                                                 img_path      AB01      AB02  \
# 0      /media/tohn/HDD/Dataset_USAI10K_Cropped/USAI_d...  0.000000  0.000000
# 28442  /media/tohn/HDD/Dataset_USAI10K_Cropped/USAI_d...  0.006173  0.005882
# 28480  /media/tohn/HDD/Dataset_USAI10K_Cropped/USAI_d...  0.000604  0.003534
# 28478  /media/tohn/HDD/Dataset_USAI10K_Cropped/USAI_d...  0.003178  0.000388
# 28477  /media/tohn/HDD/Dataset_USAI10K_Cropped/USAI_d...  0.003324  0.036729
# ...                                                  ...       ...       ...
# 25726  /media/tohn/HDD/Dataset_USAI10K_Cropped/USAI_d...  0.118637  0.151148
# 31611  /media/tohn/HDD/Dataset_USAI10K_Cropped/USAI_d...  0.015037  0.274028
# 10633  /media/tohn/HDD/Dataset_USAI10K_Cropped/USAI_d...  0.030928  0.012600
# 5032   /media/tohn/HDD/Dataset_USAI10K_Cropped/USAI_d...  0.235847  0.155054
# 9756   /media/tohn/HDD/Dataset_USAI10K_Cropped/USAI_d...  0.014803  0.019283
#
#            AB03      AB04      AB05      AB06      AB07     AB081     AB082  \
# 0      0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 28442  0.011854  0.011181  0.014163  0.006930  0.007008  0.031463  0.001338
# 28480  0.010130  0.003333  0.006737  0.008079  0.004502  0.007349  0.000635
# 28478  0.006548  0.000794  0.007414  0.003516  0.003794  0.004216  0.002735
# 28477  0.022914  0.011931  0.015669  0.015551  0.015439  0.012142  0.006750
# ...         ...       ...       ...       ...       ...       ...       ...
# 25726  0.035188  0.043291  0.032651  0.015075  0.020660  0.029381  0.057455
# 31611  0.157758  0.021830  0.053399  0.033087  0.037408  0.041176  0.006396
# 10633  0.108864  0.156603  0.147502  0.060385  0.058838  0.072872  0.017913
# 5032   0.038723  0.008480  0.025251  0.016078  0.029541  0.147807  0.022630
# 9756   0.091488  0.146127  0.138383  0.051706  0.065774  0.124020  0.016790
#
#        ...    Normal        GroupAB_Abnormolity  category_5FPvit  Prob_5FPvit  \
# 0      ...  1.000000                   ['AB05']             FP-B     0.831097
# 28442  ...  0.862930                   ['AB09']             FP-A     0.851486
# 28480  ...  0.923205                 ['Normal']             FP-C     0.844682
# 28478  ...  0.958307                 ['Normal']             FP-A     0.843097
# 28477  ...  0.772699                 ['Normal']             FP-A     0.824448
# ...    ...       ...                        ...              ...          ...
# 25726  ...  0.237296                   ['AB01']             FP-C     0.847855
# 31611  ...  0.134414   ['AB02', 'Out of class']             FP-C     0.850206
# 10633  ...  0.115868                 ['Normal']             FP-A     0.847690
# 5032   ...  0.129345  ['AB01', 'AB082', 'AB09']             FP-A     0.844616
# 9756   ...  0.123165                   ['AB05']             FP-C     0.843986
#
#        category_BiTNet  Result_BiTNet_Currect Prob_BiTNet_ofAbNor  \
# 0               Normal                      0            1.000000
# 28442           Normal                      0            1.000000
# 28480           Normal                      1            1.000000
# 28478           Normal                      1            1.000000
# 28477           Normal                      1            1.000000
# ...                ...                    ...                 ...
# 25726           Normal                      0            0.346173
# 31611           Normal                      0            0.340196
# 10633             AB12                      0            0.338263
# 5032              AB01                      1            0.329428
# 9756            Normal                      0            0.302127
#
#       Prob_BiTNet_of15AB  Doctor_ID   PID
# 0               1.000000         12   378
# 28442           0.862930         12  1241
# 28480           0.923205         12  1258
# 28478           0.958307         12  1258
# 28477           0.772699         12  1258
# ...                  ...        ...   ...
# 25726           0.237296         12   207
# 31611           0.274028         12   147
# 10633           0.156603         12   334
# 5032            0.235847         12   128
# 9756            0.146127         12   484
#
# [47705 rows x 25 columns]

# %%
dataframe_12_of15AB = dataframe_12.sort_values(by='Prob_BiTNet_of15AB', ascending=False)
dataframe_12_of15AB
# Out:
#                                                 img_path      AB01      AB02  \
# 0      /media/tohn/HDD/Dataset_USAI10K_Cropped/USAI_d...  0.000000  0.000000
# 9450   /media/tohn/HDD/Dataset_USAI10K_Cropped/USAI_d...  0.000000  0.000000
# 42084  /media/tohn/HDD/Dataset_USAI10K_Cropped/USAI_d...  0.000000  0.000000
# 42086  /media/tohn/HDD/Dataset_USAI10K_Cropped/USAI_d...  0.000000  0.000000
# 42089  /media/tohn/HDD/Dataset_USAI10K_Cropped/USAI_d...  0.000000  0.000000
# ...                                                  ...       ...       ...
# 47359  /media/tohn/HDD/Dataset_USAI10K_Cropped/USAI_d...  0.012541  0.016177
# 28361  /media/tohn/HDD/Dataset_USAI10K_Cropped/USAI_d...  0.024987  0.035525
# 37163  /media/tohn/HDD/Dataset_USAI10K_Cropped/USAI_d...  0.084771  0.117458
# 33927  /media/tohn/HDD/Dataset_USAI10K_Cropped/USAI_d...  0.031998  0.019227
# 17663  /media/tohn/HDD/Dataset_USAI10K_Cropped/USAI_d...  0.044961  0.020668
#
#            AB03      AB04      AB05      AB06      AB07     AB081     AB082  \
# 0      0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 9450   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 42084  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 42086  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 42089  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# ...         ...       ...       ...       ...       ...       ...       ...
# 47359  0.116130  0.037943  0.120705  0.057771  0.063473  0.085383  0.038120
# 28361  0.112160  0.026573  0.112916  0.088686  0.074532  0.051074  0.015472
# 37163  0.070138  0.035213  0.071200  0.042652  0.068290  0.107320  0.020510
# 33927  0.098620  0.109565  0.117842  0.058955  0.072181  0.064769  0.030416
# 17663  0.103557  0.036155  0.085408  0.069327  0.062942  0.117031  0.027472
#
#        ...    Normal  GroupAB_Abnormolity  category_5FPvit  Prob_5FPvit  \
# 0      ...  1.000000             ['AB05']             FP-B     0.831097
# 9450   ...  1.000000             ['AB05']             FP-B     0.838948
# 42084  ...  1.000000             ['AB09']             FP-B     0.836891
# 42086  ...  1.000000             ['AB09']             FP-B     0.835238
# 42089  ...  1.000000             ['AB09']             FP-C     0.850400
# ...    ...       ...                  ...              ...          ...
# 47359  ...  0.110101           ['Normal']             FP-A     0.853593
# 28361  ...  0.119923            ['AB081']             FP-C     0.849166
# 37163  ...  0.118273             ['AB01']             FP-C     0.835686
# 33927  ...  0.112909           ['Normal']             FP-C     0.851417
# 17663  ...  0.117519           ['Normal']             FP-C     0.848255
#
#        category_BiTNet  Result_BiTNet_Currect Prob_BiTNet_ofAbNor  \
# 0               Normal                      0            1.000000
# 9450            Normal                      0            1.000000
# 42084           Normal                      0            1.000000
# 42086           Normal                      0            1.000000
# 42089           Normal                      0            1.000000
# ...                ...                    ...                 ...
# 47359           Normal                      1            0.773364
# 28361           Normal                      0            0.962831
# 37163             AB02                      0            0.788239
# 33927             AB12                      0            0.821397
# 17663           Normal                      1            0.860534
#
#       Prob_BiTNet_of15AB  Doctor_ID   PID
# 0               1.000000         12   378
# 9450            1.000000         12   427
# 42084           1.000000         12   671
# 42086           1.000000         12   671
# 42089           1.000000         12   671
# ...                  ...        ...   ...
# 47359           0.120705         12  2335
# 28361           0.119923         12  1203
# 37163           0.118273         12   307
# 33927           0.117842         12   601
# 17663           0.117519         12   496
#
# [47705 rows x 25 columns]

# %%
dataframe_12_ofAbNor.to_csv('/home/yupaporn/codes/EffNet-Person-Classify/dataframe_12_ofAbNor.csv')
dataframe_12_of15AB.to_csv('/home/yupaporn/codes/EffNet-Person-Classify/dataframe_12_of15AB.csv')

# %% [markdown]
# # 🔗sort by the AI-confidence and Correct BiTNet prediction

# %%
dataframe_12_currect = dataframe_12[dataframe_12['Result_BiTNet_Currect'] == 1]
dataframe_12_currect
# Out:
#                                                 img_path      AB01      AB02  \
# 11     /media/tohn/HDD/Dataset_USAI10K_Cropped/USAI_d...  0.000000  0.000027
# 12     /media/tohn/HDD/Dataset_USAI10K_Cropped/USAI_d...  0.008902  0.030438
# 13     /media/tohn/HDD/Dataset_USAI10K_Cropped/USAI_d...  0.002586  0.003181
# 14     /media/tohn/HDD/Dataset_USAI10K_Cropped/USAI_d...  0.000391  0.004810
# 15     /media/tohn/HDD/Dataset_USAI10K_Cropped/USAI_d...  0.000154  0.002614
# ...                                                  ...       ...       ...
# 47610  /media/tohn/HDD/Dataset_USAI10K_Cropped/USAI_d...  0.021947  0.031408
# 47614  /media/tohn/HDD/Dataset_USAI10K_Cropped/USAI_d...  0.694179  0.031254
# 47615  /media/tohn/HDD/Dataset_USAI10K_Cropped/USAI_d...  0.495191  0.112408
# 47644  /media/tohn/HDD/Dataset_USAI10K_Cropped/USAI_d...  0.391022  0.104394
# 47696  /media/tohn/HDD/Dataset_USAI10K_Cropped/USAI_d...  0.042082  0.018804
#
#            AB03      AB04      AB05      AB06      AB07     AB081     AB082  \
# 11     0.000000  0.000000  0.002152  0.000000  0.000000  0.000000  0.002532
# 12     0.039087  0.018250  0.069468  0.020817  0.016492  0.022101  0.004463
# 13     0.000935  0.000463  0.001295  0.000603  0.002902  0.003023  0.000683
# 14     0.008186  0.004592  0.003902  0.002089  0.001270  0.002588  0.000683
# 15     0.007028  0.009221  0.003258  0.001891  0.003462  0.002302  0.000023
# ...         ...       ...       ...       ...       ...       ...       ...
# 47610  0.029358  0.009015  0.022891  0.010909  0.012226  0.011183  0.011354
# 47614  0.000927  0.009410  0.005016  0.000488  0.001002  0.015109  0.007521
# 47615  0.024482  0.029448  0.019619  0.013623  0.018600  0.016868  0.009612
# 47644  0.029971  0.004303  0.017635  0.014160  0.016068  0.020126  0.032677
# 47696  0.063720  0.026109  0.055935  0.036530  0.053350  0.053857  0.021948
#
#        ...    Normal  GroupAB_Abnormolity  category_5FPvit  Prob_5FPvit  \
# 11     ...  0.995289           ['Normal']             FP-A     0.850031
# 12     ...  0.707470           ['Normal']             FP-B     0.835237
# 13     ...  0.975076           ['Normal']             FP-A     0.849369
# 14     ...  0.955788           ['Normal']             FP-C     0.852270
# 15     ...  0.942821           ['Normal']             FP-C     0.852090
# ...    ...       ...                  ...              ...          ...
# 47610  ...  0.733404           ['Normal']             FP-E     0.830200
# 47614  ...  0.210655     ['AB01', 'AB11']             FP-B     0.833031
# 47615  ...  0.158194     ['AB01', 'AB11']             FP-B     0.835967
# 47644  ...  0.221059     ['AB01', 'AB11']             FP-A     0.848007
# 47696  ...  0.066202             ['AB09']             FP-C     0.848732
#
#        category_BiTNet  Result_BiTNet_Currect Prob_BiTNet_ofAbNor  \
# 11              Normal                      1            1.000000
# 12              Normal                      1            1.000000
# 13              Normal                      1            1.000000
# 14              Normal                      1            1.000000
# 15              Normal                      1            1.000000
# ...                ...                    ...                 ...
# 47610           Normal                      1            0.999979
# 47614             AB01                      1            0.963214
# 47615             AB01                      1            0.987397
# 47644             AB01                      1            0.560643
# 47696             AB09                      1            0.561741
#
#       Prob_BiTNet_of15AB  Doctor_ID   PID
# 11              0.995289         12   416
# 12              0.707470         12   416
# 13              0.975076         12   416
# 14              0.955788         12   416
# 15              0.942821         12   416
# ...                  ...        ...   ...
# 47610           0.733404         12  4381
# 47614           0.694179         12  4426
# 47615           0.495191         12  4426
# 47644           0.391022         12  4767
# 47696           0.292228         12  6207
#
# [24313 rows x 25 columns]

# %%
dataframe_12_currect_ofAbNor = dataframe_12_currect.sort_values(by='Prob_BiTNet_ofAbNor', ascending=False)
dataframe_12_currect_ofAbNor
# Out:
#                                                 img_path      AB01      AB02  \
# 11     /media/tohn/HDD/Dataset_USAI10K_Cropped/USAI_d...  0.000000  0.000027
# 31273  /media/tohn/HDD/Dataset_USAI10K_Cropped/USAI_d...  0.000000  0.000000
# 31282  /media/tohn/HDD/Dataset_USAI10K_Cropped/USAI_d...  0.002646  0.008526
# 31281  /media/tohn/HDD/Dataset_USAI10K_Cropped/USAI_d...  0.000000  0.000000
# 31280  /media/tohn/HDD/Dataset_USAI10K_Cropped/USAI_d...  0.000000  0.000000
# ...                                                  ...       ...       ...
# 9830   /media/tohn/HDD/Dataset_USAI10K_Cropped/USAI_d...  0.222813  0.226642
# 22998  /media/tohn/HDD/Dataset_USAI10K_Cropped/USAI_d...  0.009445  0.018939
# 10345  /media/tohn/HDD/Dataset_USAI10K_Cropped/USAI_d...  0.011173  0.032801
# 41758  /media/tohn/HDD/Dataset_USAI10K_Cropped/USAI_d...  0.019000  0.029236
# 5032   /media/tohn/HDD/Dataset_USAI10K_Cropped/USAI_d...  0.235847  0.155054
#
#            AB03      AB04      AB05      AB06      AB07     AB081     AB082  \
# 11     0.000000  0.000000  0.002152  0.000000  0.000000  0.000000  0.002532
# 31273  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 31282  0.006342  0.000042  0.006667  0.000390  0.000653  0.002566  0.000000
# 31281  0.000000  0.000000  0.000000  0.000000  0.000000  0.002500  0.000000
# 31280  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# ...         ...       ...       ...       ...       ...       ...       ...
# 9830   0.057513  0.020290  0.039382  0.025015  0.031441  0.059298  0.036613
# 22998  0.048062  0.018980  0.043144  0.024792  0.019131  0.036920  0.005536
# 10345  0.051638  0.379189  0.115536  0.023991  0.030365  0.071334  0.008453
# 41758  0.033725  0.460330  0.015469  0.005173  0.006581  0.015478  0.009527
# 5032   0.038723  0.008480  0.025251  0.016078  0.029541  0.147807  0.022630
#
#        ...    Normal        GroupAB_Abnormolity  category_5FPvit  Prob_5FPvit  \
# 11     ...  0.995289                 ['Normal']             FP-A     0.850031
# 31273  ...  1.000000                 ['Normal']             FP-B     0.839009
# 31282  ...  0.963563                 ['Normal']             FP-B     0.839127
# 31281  ...  0.990000                 ['Normal']             FP-C     0.851870
# 31280  ...  1.000000                 ['Normal']             FP-C     0.851577
# ...    ...       ...                        ...              ...          ...
# 9830   ...  0.145436                   ['AB01']             FP-B     0.838836
# 22998  ...  0.106063                   ['AB11']             FP-C     0.847953
# 10345  ...  0.136637                   ['AB05']             FP-B     0.835642
# 41758  ...  0.209642                   ['AB04']             FP-C     0.848198
# 5032   ...  0.129345  ['AB01', 'AB082', 'AB09']             FP-A     0.844616
#
#        category_BiTNet  Result_BiTNet_Currect Prob_BiTNet_ofAbNor  \
# 11              Normal                      1            1.000000
# 31273           Normal                      1            1.000000
# 31282           Normal                      1            1.000000
# 31281           Normal                      1            1.000000
# 31280           Normal                      1            1.000000
# ...                ...                    ...                 ...
# 9830              AB01                      1            0.459330
# 22998             AB11                      1            0.418612
# 10345             AB05                      1            0.406106
# 41758             AB04                      1            0.389769
# 5032              AB01                      1            0.329428
#
#       Prob_BiTNet_of15AB  Doctor_ID  PID
# 11              0.995289         12  416
# 31273           1.000000         12   89
# 31282           0.963563         12   89
# 31281           0.990000         12   89
# 31280           1.000000         12   89
# ...                  ...        ...  ...
# 9830            0.226642         12  502
# 22998           0.517102         12   15
# 10345           0.379189         12  161
# 41758           0.460330         12  565
# 5032            0.235847         12  128
#
# [24313 rows x 25 columns]

# %%
dataframe_12_currect_of15AB = dataframe_12_currect.sort_values(by='Prob_BiTNet_of15AB', ascending=False)
dataframe_12_currect_of15AB
# Out:
#                                                 img_path      AB01      AB02  \
# 39353  /media/tohn/HDD/Dataset_USAI10K_Cropped/USAI_d...  0.000000  0.000000
# 44106  /media/tohn/HDD/Dataset_USAI10K_Cropped/USAI_d...  0.000000  0.000000
# 44120  /media/tohn/HDD/Dataset_USAI10K_Cropped/USAI_d...  0.000000  0.000000
# 44119  /media/tohn/HDD/Dataset_USAI10K_Cropped/USAI_d...  0.000000  0.000000
# 44118  /media/tohn/HDD/Dataset_USAI10K_Cropped/USAI_d...  0.000000  0.000000
# ...                                                  ...       ...       ...
# 10370  /media/tohn/HDD/Dataset_USAI10K_Cropped/USAI_d...  0.018104  0.019893
# 13632  /media/tohn/HDD/Dataset_USAI10K_Cropped/USAI_d...  0.019220  0.037343
# 18420  /media/tohn/HDD/Dataset_USAI10K_Cropped/USAI_d...  0.068957  0.064973
# 47359  /media/tohn/HDD/Dataset_USAI10K_Cropped/USAI_d...  0.012541  0.016177
# 17663  /media/tohn/HDD/Dataset_USAI10K_Cropped/USAI_d...  0.044961  0.020668
#
#            AB03      AB04      AB05      AB06      AB07     AB081     AB082  \
# 39353  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 44106  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 44120  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 44119  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 44118  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# ...         ...       ...       ...       ...       ...       ...       ...
# 10370  0.115344  0.104111  0.115658  0.051249  0.054402  0.126073  0.015575
# 13632  0.109177  0.110833  0.119476  0.079137  0.065350  0.079880  0.009588
# 18420  0.082922  0.034242  0.078147  0.069667  0.066132  0.100168  0.015016
# 47359  0.116130  0.037943  0.120705  0.057771  0.063473  0.085383  0.038120
# 17663  0.103557  0.036155  0.085408  0.069327  0.062942  0.117031  0.027472
#
#        ...    Normal  GroupAB_Abnormolity  category_5FPvit  Prob_5FPvit  \
# 39353  ...  1.000000           ['Normal']             FP-C     0.850579
# 44106  ...  1.000000           ['Normal']             FP-D     0.847240
# 44120  ...  1.000000           ['Normal']             FP-C     0.850326
# 44119  ...  1.000000           ['Normal']             FP-C     0.846196
# 44118  ...  1.000000           ['Normal']             FP-D     0.845072
# ...    ...       ...                  ...              ...          ...
# 10370  ...  0.140060           ['Normal']             FP-B     0.836144
# 13632  ...  0.128480           ['Normal']             FP-C     0.838963
# 18420  ...  0.124016           ['Normal']             FP-C     0.850655
# 47359  ...  0.110101           ['Normal']             FP-A     0.853593
# 17663  ...  0.117519           ['Normal']             FP-C     0.848255
#
#        category_BiTNet  Result_BiTNet_Currect Prob_BiTNet_ofAbNor  \
# 39353           Normal                      1            1.000000
# 44106           Normal                      1            1.000000
# 44120           Normal                      1            1.000000
# 44119           Normal                      1            1.000000
# 44118           Normal                      1            1.000000
# ...                ...                    ...                 ...
# 10370           Normal                      1            0.696758
# 13632           Normal                      1            0.934636
# 18420           Normal                      1            0.913070
# 47359           Normal                      1            0.773364
# 17663           Normal                      1            0.860534
#
#       Prob_BiTNet_of15AB  Doctor_ID   PID
# 39353           1.000000         12   914
# 44106           1.000000         12  7401
# 44120           1.000000         12  7405
# 44119           1.000000         12  7405
# 44118           1.000000         12  7405
# ...                  ...        ...   ...
# 10370           0.140060         12   175
# 13632           0.128480         12   288
# 18420           0.124016         12   100
# 47359           0.120705         12  2335
# 17663           0.117519         12   496
#
# [24313 rows x 25 columns]

# %%
dataframe_12_currect_ofAbNor.to_csv('/home/yupaporn/codes/EffNet-Person-Classify/dataframe_12_currect_ofAbNor.csv')
dataframe_12_currect_of15AB.to_csv('/home/yupaporn/codes/EffNet-Person-Classify/dataframe_12_currect_of15AB.csv')
